# %%
# %pip install svetlanna
# %pip install reservoirpy matplotlib tqdm requests av scikit-image py-cpuinfo gputil pandas
# Out:
# Requirement already satisfied: svetlanna in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (1.0.2)
# Requirement already satisfied: anywidget<0.10.0,>=0.9.13 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from svetlanna) (0.9.18)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.6 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from svetlanna) (3.1.6)
# Requirement already satisfied: matplotlib<3.9.2 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from svetlanna) (3.9.1.post1)
# Requirement already satisfied: numpy<2.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from svetlanna) (1.26.4)
# Requirement already satisfied: ipywidgets>=7.6.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from anywidget<0.10.0,>=0.9.13->svetlanna) (8.1.5)
# Requirement already satisfied: psygnal>=0.8.1 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from anywidget<0.10.0,>=0.9.13->svetlanna) (0.12.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from anywidget<0.10.0,>=0.9.13->svetlanna) (4.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from jinja2<4.0.0,>=3.1.6->svetlanna) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib<3.9.2->svetlanna) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib<3.9.2->svetlanna) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib<3.9.2->svetlanna) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib<3.9.2->svetlanna) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib<3.9.2->svetlanna) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib<3.9.2->svetlanna) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib<3.9.2->svetlanna) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib<3.9.2->svetlanna) (2.9.0.post0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (9.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (3.0.13)
# Requirement already satisfied: six>=1.5 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.9.2->svetlanna) (1.17.0)
# Requirement already satisfied: colorama in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (0.4.6)
# Requirement already satisfied: decorator in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->anywidget<0.10.0,>=0.9.13->svetlanna) (0.2.3)
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting reservoirpy
#   Downloading reservoirpy-0.3.13.post1-py3-none-any.whl (209 kB)
#                                               0.0/209.8 kB ? eta -:--:--
#      -----                                    30.7/209.8 kB ? eta -:--:--
#      -----------------                       92.2/209.8 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 209.8/209.8 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (3.9.1.post1)
# Requirement already satisfied: tqdm in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (4.67.1)
# Requirement already satisfied: requests in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (2.32.3)
# Collecting av
#   Downloading av-15.0.0-cp311-cp311-win_amd64.whl (31.4 MB)
#                                               0.0/31.4 MB ? eta -:--:--
#                                               0.2/31.4 MB 13.4 MB/s eta 0:00:03
#                                               0.4/31.4 MB 5.3 MB/s eta 0:00:06
#                                               0.7/31.4 MB 4.6 MB/s eta 0:00:07
#      -                                        0.9/31.4 MB 4.8 MB/s eta 0:00:07
#      -                                        1.1/31.4 MB 5.1 MB/s eta 0:00:06
#      -                                        1.3/31.4 MB 5.3 MB/s eta 0:00:06
#      --                                       1.6/31.4 MB 5.1 MB/s eta 0:00:06
#      --                                       1.6/31.4 MB 5.1 MB/s eta 0:00:06
#      --                                       1.6/31.4 MB 4.1 MB/s eta 0:00:08
#      --                                       1.9/31.4 MB 4.6 MB/s eta 0:00:07
#      --                                       2.0/31.4 MB 4.1 MB/s eta 0:00:08
#      --                                       2.2/31.4 MB 4.2 MB/s eta 0:00:07
#      ---                                      2.5/31.4 MB 4.3 MB/s eta 0:00:07
#      ---                                      2.8/31.4 MB 4.4 MB/s eta 0:00:07
#      ---                                      3.0/31.4 MB 4.4 MB/s eta 0:00:07
#      ----                                     3.2/31.4 MB 4.5 MB/s eta 0:00:07
#      ----                                     3.5/31.4 MB 4.6 MB/s eta 0:00:07
#      ----                                     3.8/31.4 MB 4.7 MB/s eta 0:00:06
#      -----                                    4.1/31.4 MB 4.8 MB/s eta 0:00:06
#      -----                                    4.4/31.4 MB 4.7 MB/s eta 0:00:06
#      -----                                    4.7/31.4 MB 4.9 MB/s eta 0:00:06
#      ------                                   4.9/31.4 MB 4.8 MB/s eta 0:00:06
#      ------                                   5.2/31.4 MB 4.9 MB/s eta 0:00:06
#      ------                                   5.5/31.4 MB 4.9 MB/s eta 0:00:06
#      -------                                  5.8/31.4 MB 5.0 MB/s eta 0:00:06
#      -------                                  6.1/31.4 MB 5.0 MB/s eta 0:00:06
#      --------                                 6.4/31.4 MB 5.0 MB/s eta 0:00:05
#      --------                                 6.6/31.4 MB 5.0 MB/s eta 0:00:05
#      --------                                 6.9/31.4 MB 5.0 MB/s eta 0:00:05
#      ---------                                7.1/31.4 MB 5.1 MB/s eta 0:00:05
#      ---------                                7.2/31.4 MB 5.0 MB/s eta 0:00:05
#      ---------                                7.3/31.4 MB 4.9 MB/s eta 0:00:05
#      ---------                                7.4/31.4 MB 4.8 MB/s eta 0:00:05
#      ---------                                7.7/31.4 MB 4.8 MB/s eta 0:00:05
#      ---------                                7.8/31.4 MB 4.7 MB/s eta 0:00:05
#      ----------                               8.1/31.4 MB 4.8 MB/s eta 0:00:05
#      ----------                               8.3/31.4 MB 4.8 MB/s eta 0:00:05
#      ----------                               8.6/31.4 MB 4.8 MB/s eta 0:00:05
#      -----------                              8.9/31.4 MB 4.9 MB/s eta 0:00:05
#      -----------                              9.2/31.4 MB 4.9 MB/s eta 0:00:05
#      ------------                             9.4/31.4 MB 4.9 MB/s eta 0:00:05
#      ------------                             9.7/31.4 MB 4.9 MB/s eta 0:00:05
#      ------------                             10.0/31.4 MB 5.0 MB/s eta 0:00:05
#      -------------                            10.2/31.4 MB 5.0 MB/s eta 0:00:05
#      -------------                            10.5/31.4 MB 5.0 MB/s eta 0:00:05
#      -------------                            10.7/31.4 MB 5.0 MB/s eta 0:00:05
#      --------------                           11.0/31.4 MB 5.1 MB/s eta 0:00:05
#      --------------                           11.3/31.4 MB 5.1 MB/s eta 0:00:04
#      --------------                           11.5/31.4 MB 5.1 MB/s eta 0:00:04
#      --------------                           11.8/31.4 MB 5.1 MB/s eta 0:00:04
#      ---------------                          12.1/31.4 MB 5.3 MB/s eta 0:00:04
#      ---------------                          12.4/31.4 MB 5.5 MB/s eta 0:00:04
#      ----------------                         12.7/31.4 MB 5.4 MB/s eta 0:00:04
#      ----------------                         13.0/31.4 MB 5.5 MB/s eta 0:00:04
#      ----------------                         13.3/31.4 MB 5.5 MB/s eta 0:00:04
#      -----------------                        13.5/31.4 MB 5.5 MB/s eta 0:00:04
#      -----------------                        13.8/31.4 MB 5.5 MB/s eta 0:00:04
#      -----------------                        14.1/31.4 MB 5.6 MB/s eta 0:00:04
#      ------------------                       14.4/31.4 MB 5.5 MB/s eta 0:00:04
#      ------------------                       14.6/31.4 MB 5.5 MB/s eta 0:00:04
#      ------------------                       14.7/31.4 MB 5.4 MB/s eta 0:00:04
#      ------------------                       14.8/31.4 MB 5.3 MB/s eta 0:00:04
#      -------------------                      15.0/31.4 MB 5.2 MB/s eta 0:00:04
#      -------------------                      15.1/31.4 MB 5.2 MB/s eta 0:00:04
#      -------------------                      15.2/31.4 MB 5.2 MB/s eta 0:00:04
#      -------------------                      15.5/31.4 MB 5.1 MB/s eta 0:00:04
#      --------------------                     15.8/31.4 MB 5.2 MB/s eta 0:00:04
#      --------------------                     16.0/31.4 MB 5.2 MB/s eta 0:00:03
#      --------------------                     16.4/31.4 MB 5.1 MB/s eta 0:00:03
#      ---------------------                    16.7/31.4 MB 5.2 MB/s eta 0:00:03
#      ---------------------                    17.0/31.4 MB 5.2 MB/s eta 0:00:03
#      ---------------------                    17.2/31.4 MB 5.2 MB/s eta 0:00:03
#      ----------------------                   17.5/31.4 MB 5.4 MB/s eta 0:00:03
#      ----------------------                   17.8/31.4 MB 5.6 MB/s eta 0:00:03
#      -----------------------                  18.1/31.4 MB 5.6 MB/s eta 0:00:03
#      -----------------------                  18.3/31.4 MB 5.6 MB/s eta 0:00:03
#      -----------------------                  18.4/31.4 MB 5.6 MB/s eta 0:00:03
#      -----------------------                  18.5/31.4 MB 5.5 MB/s eta 0:00:03
#      -----------------------                  18.6/31.4 MB 5.4 MB/s eta 0:00:03
#      ------------------------                 18.9/31.4 MB 5.4 MB/s eta 0:00:03
#      ------------------------                 19.1/31.4 MB 5.3 MB/s eta 0:00:03
#      ------------------------                 19.4/31.4 MB 5.3 MB/s eta 0:00:03
#      -------------------------                19.7/31.4 MB 5.3 MB/s eta 0:00:03
#      -------------------------                20.0/31.4 MB 5.4 MB/s eta 0:00:03
#      -------------------------                20.4/31.4 MB 5.4 MB/s eta 0:00:03
#      --------------------------               20.7/31.4 MB 5.4 MB/s eta 0:00:02
#      --------------------------               21.0/31.4 MB 5.4 MB/s eta 0:00:02
#      ---------------------------              21.3/31.4 MB 5.4 MB/s eta 0:00:02
#      ---------------------------              21.6/31.4 MB 5.4 MB/s eta 0:00:02
#      ----------------------------             22.0/31.4 MB 5.4 MB/s eta 0:00:02
#      ----------------------------             22.3/31.4 MB 5.4 MB/s eta 0:00:02
#      ----------------------------             22.6/31.4 MB 5.4 MB/s eta 0:00:02
#      -----------------------------            22.9/31.4 MB 5.5 MB/s eta 0:00:02
#      -----------------------------            23.1/31.4 MB 5.4 MB/s eta 0:00:02
#      -----------------------------            23.4/31.4 MB 5.5 MB/s eta 0:00:02
#      ------------------------------           23.8/31.4 MB 5.5 MB/s eta 0:00:02
#      ------------------------------           24.0/31.4 MB 5.5 MB/s eta 0:00:02
#      -------------------------------          24.4/31.4 MB 5.6 MB/s eta 0:00:02
#      -------------------------------          24.6/31.4 MB 5.5 MB/s eta 0:00:02
#      -------------------------------          25.0/31.4 MB 5.7 MB/s eta 0:00:02
#      --------------------------------         25.2/31.4 MB 5.9 MB/s eta 0:00:02
#      --------------------------------         25.6/31.4 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------        25.9/31.4 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------        26.2/31.4 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------        26.5/31.4 MB 6.1 MB/s eta 0:00:01
#      ----------------------------------       26.7/31.4 MB 6.1 MB/s eta 0:00:01
#      ----------------------------------       27.1/31.4 MB 6.1 MB/s eta 0:00:01
#      ----------------------------------       27.4/31.4 MB 6.1 MB/s eta 0:00:01
#      -----------------------------------      27.7/31.4 MB 6.2 MB/s eta 0:00:01
#      -----------------------------------      28.1/31.4 MB 6.2 MB/s eta 0:00:01
#      ------------------------------------     28.4/31.4 MB 6.1 MB/s eta 0:00:01
#      ------------------------------------     28.7/31.4 MB 6.4 MB/s eta 0:00:01
#      -------------------------------------    29.1/31.4 MB 6.5 MB/s eta 0:00:01
#      -------------------------------------    29.4/31.4 MB 6.7 MB/s eta 0:00:01
#      -------------------------------------    29.6/31.4 MB 6.7 MB/s eta 0:00:01
#      --------------------------------------   30.0/31.4 MB 6.7 MB/s eta 0:00:01
#      --------------------------------------   30.3/31.4 MB 6.7 MB/s eta 0:00:01
#      ---------------------------------------  30.6/31.4 MB 6.7 MB/s eta 0:00:01
#      ---------------------------------------  30.9/31.4 MB 6.7 MB/s eta 0:00:01
#      ---------------------------------------  31.2/31.4 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------------  31.4/31.4 MB 6.7 MB/s eta 0:00:01
#      ---------------------------------------  31.4/31.4 MB 6.7 MB/s eta 0:00:01
#      ---------------------------------------- 31.4/31.4 MB 6.5 MB/s eta 0:00:00
# Collecting scikit-image
#   Downloading scikit_image-0.25.2-cp311-cp311-win_amd64.whl (12.8 MB)
#                                               0.0/12.8 MB ? eta -:--:--
#                                               0.1/12.8 MB 4.3 MB/s eta 0:00:03
#                                               0.3/12.8 MB 3.2 MB/s eta 0:00:04
#      -                                        0.5/12.8 MB 3.8 MB/s eta 0:00:04
#      -                                        0.6/12.8 MB 3.2 MB/s eta 0:00:04
#      --                                       0.7/12.8 MB 3.4 MB/s eta 0:00:04
#      --                                       0.8/12.8 MB 3.2 MB/s eta 0:00:04
#      --                                       0.9/12.8 MB 2.7 MB/s eta 0:00:05
#      ---                                      1.0/12.8 MB 2.8 MB/s eta 0:00:05
#      ---                                      1.0/12.8 MB 2.7 MB/s eta 0:00:05
#      ---                                      1.2/12.8 MB 2.7 MB/s eta 0:00:05
#      ---                                      1.3/12.8 MB 2.6 MB/s eta 0:00:05
#      ----                                     1.4/12.8 MB 2.6 MB/s eta 0:00:05
#      ----                                     1.5/12.8 MB 2.5 MB/s eta 0:00:05
#      -----                                    1.6/12.8 MB 2.6 MB/s eta 0:00:05
#      -----                                    1.8/12.8 MB 2.6 MB/s eta 0:00:05
#      -----                                    1.9/12.8 MB 2.6 MB/s eta 0:00:05
#      ------                                   2.0/12.8 MB 2.5 MB/s eta 0:00:05
#      ------                                   2.1/12.8 MB 2.5 MB/s eta 0:00:05
#      -------                                  2.3/12.8 MB 2.6 MB/s eta 0:00:05
#      -------                                  2.3/12.8 MB 2.6 MB/s eta 0:00:05
#      -------                                  2.4/12.8 MB 2.6 MB/s eta 0:00:05
#      -------                                  2.5/12.8 MB 2.5 MB/s eta 0:00:05
#      --------                                 2.6/12.8 MB 2.5 MB/s eta 0:00:05
#      --------                                 2.7/12.8 MB 2.5 MB/s eta 0:00:04
#      --------                                 2.8/12.8 MB 2.5 MB/s eta 0:00:04
#      ---------                                3.0/12.8 MB 2.6 MB/s eta 0:00:04
#      ---------                                3.1/12.8 MB 2.6 MB/s eta 0:00:04
#      ----------                               3.2/12.8 MB 2.6 MB/s eta 0:00:04
#      ----------                               3.3/12.8 MB 2.6 MB/s eta 0:00:04
#      ----------                               3.4/12.8 MB 2.6 MB/s eta 0:00:04
#      -----------                              3.5/12.8 MB 2.6 MB/s eta 0:00:04
#      -----------                              3.6/12.8 MB 2.6 MB/s eta 0:00:04
#      -----------                              3.7/12.8 MB 2.6 MB/s eta 0:00:04
#      ------------                             3.8/12.8 MB 2.6 MB/s eta 0:00:04
#      ------------                             3.9/12.8 MB 2.5 MB/s eta 0:00:04
#      ------------                             4.1/12.8 MB 2.5 MB/s eta 0:00:04
#      -------------                            4.2/12.8 MB 2.6 MB/s eta 0:00:04
#      -------------                            4.3/12.8 MB 2.6 MB/s eta 0:00:04
#      -------------                            4.4/12.8 MB 2.6 MB/s eta 0:00:04
#      --------------                           4.5/12.8 MB 2.5 MB/s eta 0:00:04
#      --------------                           4.7/12.8 MB 2.6 MB/s eta 0:00:04
#      --------------                           4.8/12.8 MB 2.6 MB/s eta 0:00:04
#      ---------------                          4.9/12.8 MB 2.6 MB/s eta 0:00:04
#      ---------------                          5.0/12.8 MB 2.5 MB/s eta 0:00:04
#      ---------------                          5.1/12.8 MB 2.5 MB/s eta 0:00:04
#      ----------------                         5.2/12.8 MB 2.5 MB/s eta 0:00:03
#      ----------------                         5.3/12.8 MB 2.5 MB/s eta 0:00:03
#      ----------------                         5.4/12.8 MB 2.5 MB/s eta 0:00:03
#      -----------------                        5.5/12.8 MB 2.5 MB/s eta 0:00:03
#      -----------------                        5.6/12.8 MB 2.5 MB/s eta 0:00:03
#      -------------------                      6.1/12.8 MB 2.7 MB/s eta 0:00:03
#      --------------------                     6.5/12.8 MB 2.8 MB/s eta 0:00:03
#      ---------------------                    7.0/12.8 MB 2.9 MB/s eta 0:00:02
#      -----------------------                  7.4/12.8 MB 3.1 MB/s eta 0:00:02
#      ------------------------                 7.8/12.8 MB 3.2 MB/s eta 0:00:02
#      --------------------------               8.3/12.8 MB 3.3 MB/s eta 0:00:02
#      ---------------------------              8.9/12.8 MB 3.5 MB/s eta 0:00:02
#      ----------------------------             9.0/12.8 MB 3.5 MB/s eta 0:00:02
#      ----------------------------             9.2/12.8 MB 3.5 MB/s eta 0:00:02
#      -----------------------------            9.3/12.8 MB 3.5 MB/s eta 0:00:01
#      -----------------------------            9.5/12.8 MB 3.5 MB/s eta 0:00:01
#      ------------------------------           9.6/12.8 MB 3.5 MB/s eta 0:00:01
#      ------------------------------           9.7/12.8 MB 3.4 MB/s eta 0:00:01
#      ------------------------------           9.8/12.8 MB 3.4 MB/s eta 0:00:01
#      ------------------------------           9.9/12.8 MB 3.4 MB/s eta 0:00:01
#      -------------------------------          10.0/12.8 MB 3.4 MB/s eta 0:00:01
#      -------------------------------          10.1/12.8 MB 3.4 MB/s eta 0:00:01
#      -------------------------------          10.1/12.8 MB 3.3 MB/s eta 0:00:01
#      --------------------------------         10.3/12.8 MB 3.3 MB/s eta 0:00:01
#      --------------------------------         10.4/12.8 MB 3.3 MB/s eta 0:00:01
#      --------------------------------         10.5/12.8 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------        10.7/12.8 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------        10.8/12.8 MB 3.3 MB/s eta 0:00:01
#      ----------------------------------       10.9/12.8 MB 3.3 MB/s eta 0:00:01
#      ----------------------------------       11.0/12.8 MB 3.3 MB/s eta 0:00:01
#      ----------------------------------       11.2/12.8 MB 3.3 MB/s eta 0:00:01
#      -----------------------------------      11.3/12.8 MB 3.3 MB/s eta 0:00:01
#      -----------------------------------      11.4/12.8 MB 3.3 MB/s eta 0:00:01
#      -----------------------------------      11.5/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------------     11.6/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------------     11.7/12.8 MB 3.3 MB/s eta 0:00:01
#      ------------------------------------     11.8/12.8 MB 3.4 MB/s eta 0:00:01
#      -------------------------------------    12.0/12.8 MB 3.3 MB/s eta 0:00:01
#      -------------------------------------    12.1/12.8 MB 3.3 MB/s eta 0:00:01
#      --------------------------------------   12.2/12.8 MB 3.4 MB/s eta 0:00:01
#      --------------------------------------   12.3/12.8 MB 3.3 MB/s eta 0:00:01
#      --------------------------------------   12.4/12.8 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  12.5/12.8 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: py-cpuinfo in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (9.0.0)
# Requirement already satisfied: gputil in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (1.4.0)
# Collecting dill>=0.3.1.1 (from reservoirpy)
#   Downloading dill-0.4.0-py3-none-any.whl (119 kB)
#                                               0.0/119.7 kB ? eta -:--:--
#      -------------------------------------- 119.7/119.7 kB 7.3 MB/s eta 0:00:00
# Collecting joblib>=0.14.1 (from reservoirpy)
#   Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#                                               0.0/307.7 kB ? eta -:--:--
#      -------------------------------------- 307.7/307.7 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.1 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from reservoirpy) (1.26.4)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from reservoirpy) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: networkx>=3.0 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from scikit-image) (3.3)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
#                                               0.0/315.8 kB ? eta -:--:--
#      ------------------------------------- 315.8/315.8 kB 19.1 MB/s eta 0:00:00
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2025.6.11-py3-none-any.whl (230 kB)
#                                               0.0/230.8 kB ? eta -:--:--
#      ------------------------------------- 230.8/230.8 kB 14.7 MB/s eta 0:00:00
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: six>=1.5 in c:\users\gunne\projects\python\dnn\svetlanna.docs\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: tifffile, lazy-loader, joblib, imageio, dill, av, scikit-image, reservoirpy
# Successfully installed av-15.0.0 dill-0.4.0 imageio-2.37.0 joblib-1.5.1 lazy-loader-0.4 reservoirpy-0.3.13.post1 scikit-image-0.25.2 tifffile-2025.6.11
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
import matplotlib.pyplot as plt

from svetlanna import elements
from svetlanna import SimulationParameters
from svetlanna import wavefront as w
from svetlanna.units import ureg

# %% [markdown]
# # Дифракция на апертурах различной формы
#
# В этом примере приведено решение задачи дифракции плоской волны на апертурах различной формы с использованием объектов из модуля `svetlanna.elements`

# %% [markdown]
# ## Создание расчетной сетки и использованием класса `SimulationParameters`

# %%
# размер экрана, мм
lx = 8 * ureg.mm
ly = 8 * ureg.mm

# расстояние между экраном и апертурой, мм
z = 220 * ureg.mm

# длина волны, нм
wavelength = 1064 * ureg.nm

# количество расчетных точек по горизонтали и вертикали
Nx = 1024
Ny = 1024

# создание расчетной сетки
sim_params = SimulationParameters({
    'W': torch.linspace(-lx / 2, lx / 2, Nx),
    'H': torch.linspace(-ly / 2, ly / 2, Ny),
    'wavelength': wavelength,
})

# %%
# создание двухмерной сетки по осям W и H
x_grid, y_grid = sim_params.meshgrid(x_axis='W', y_axis='H')

# %% [markdown]
# ## Создание плоской волны с использованием `svetlanna.wavefront.plane_wave`
#
# Создадим плоскую волну, которая падает на поверхность апертуры:

# %%
# создание плоской волны
incident_field = w.Wavefront.plane_wave(
    simulation_parameters=sim_params,
    distance=0 * ureg.cm,
    wave_direction=[0, 0, 1]
)

# %% [markdown]
# ## Создание круглой апертуры с использованием класса `svetlanna.elements.RoundAperture`

# %%
radius = 1 * ureg.mm

round_aperture = elements.RoundAperture(
    simulation_parameters=sim_params,
    radius=radius,
)

# %% [markdown]
# Посмотрим как выглядит функция пропускания апертуры с использованием метода класса `.get_transmission_function()`:

# %%
aperture_transmission_function = round_aperture.get_transmission_function()

# %%
fig, ax = plt.subplots(figsize=(6, 3), edgecolor='black', linewidth=3,
                       frameon=True)
im1 = ax.pcolormesh(x_grid, y_grid, aperture_transmission_function, cmap='inferno')
ax.set_aspect('equal')
ax.set_title('Форма круглой апертуры')
ax.set_xlabel('$x$ [m]')
ax.set_ylabel('$y$ [m]')
fig.colorbar(im1, label='Функция пропускания')

# %% [markdown]
# ## Распределение интенсивности на экране после распространения плоской волны через круглую апертуру
#
# В этой части решена прямая задача дифракции на апертуре круглой формы с использованием метода углового спектра из класса `FreeSpace`

# %%
field_after_aperture = round_aperture.forward(
    incident_wavefront=incident_field
)

free_space = elements.FreeSpace(
    simulation_parameters=sim_params,
    distance=z,
    method="AS"
)

output_wavefront = free_space.forward(
    incident_wavefront=field_after_aperture
)

output_intensity = output_wavefront.intensity

# %% [markdown]
# Визуализируем рассчитанное распределение интенсивности:

# %%
fig, ax = plt.subplots(figsize=(6, 3), edgecolor='black', linewidth=3,
                       frameon=True)
im1 = ax.pcolormesh(x_grid, y_grid, output_intensity, cmap='inferno')
ax.set_aspect('equal')
ax.set_title('Распределение интенсивности на экране')
ax.set_xlabel('$x$ [м]')
ax.set_ylabel('$y$ [м]')
fig.colorbar(im1, label='интенсивность')

# %% [markdown]
# ## Создание апертуры произвольной формы
#
# В качестве примера создадим апертуру похожую на мягкую апертуру из статьи [[1]](https://opg.optica.org/ao/abstract.cfm?uri=ao-59-18-5348)
#
# Форма апертуры определяется выражением:
#
# $$
# r=R + S(\theta)=R(1 + \dfrac{s}{2}(1 + \sin{M\theta})),
# $$
#
# где $R$ - радиус круглой апертуры, $M$ - количество зубцов, $s$ - отношение $h$ к $r$.

# %% [markdown]
# Создадим апертуру заданной формы:

# %%
radius_soft = 1 * ureg.mm

r = torch.sqrt(x_grid**2 + y_grid**2)
M = 32

s = 0.1

theta = torch.atan2(y_grid, x_grid)
shape = r *( 1 + s / 2 *(1 + torch.sin(M*theta)))
shape = shape < 0.0015

# %% [markdown]
# Создадим нужную апертуру с использованием класса `Aperture` из модуля `svetlanna.elements`

# %%
soft_aperture = elements.Aperture(simulation_parameters=sim_params, mask=shape)

# %% [markdown]
# Посмотрим форму апертуры с использованием метода класса `.get_transmission_function()`:

# %%
aperture_transmission_function = soft_aperture.get_transmission_function()

# %%
fig, ax = plt.subplots(figsize=(6, 3), edgecolor='black', linewidth=3,
                       frameon=True)
im1 = ax.pcolormesh(x_grid, y_grid, aperture_transmission_function, cmap='inferno')
ax.set_aspect('equal')
ax.set_title('Форма мягкой апертуры')
ax.set_xlabel('$x$ [m]')
ax.set_ylabel('$y$ [m]')
fig.colorbar(im1, label='Функция пропускания')

# %% [markdown]
# ## Распределение интенсивности после прохождения мягкой апертуры
#
# В этой части решим прямую задачу дифракции на мягкой апертуры с использованием метода углового спектра

# %%
field_after_aperture = soft_aperture.forward(
    incident_wavefront=incident_field
)

free_space = elements.FreeSpace(
    simulation_parameters=sim_params,
    distance=z,
    method="AS"
)

output_wavefront = free_space.forward(
    incident_wavefront=field_after_aperture
)

output_intensity = output_wavefront.intensity

# %% [markdown]
# Визуализируем распределение интенсивности на экране:

# %%
fig, ax = plt.subplots(figsize=(6, 3), edgecolor='black', linewidth=3,
                       frameon=True)
im1 = ax.pcolormesh(x_grid, y_grid, output_intensity, cmap='inferno')
ax.set_aspect('equal')
ax.set_title('Распределение интенсивности на\nэкране после прохождения мягкой апертуры')
ax.set_xlabel('$x$ [m]')
ax.set_ylabel('$y$ [m]')
fig.colorbar(im1, label='интенсивность')
